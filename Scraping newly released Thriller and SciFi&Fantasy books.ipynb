# %% [markdown]
# In this notebook we attempt to scrape and gather newly relased fiction books ordered by subjects from [Barnes&Noble](https://www.barnesandnoble.com/). We collect our data as follows:
# - scrape to get the list of subjects used to categorize the fiction books.
# - for each subject we will accumulate 40 different books along with the title, author, and summary(if it exists) for each book in the subject.
# <br>if a summary does not exist, and if we are missing just a few then we should be able to manually replace using targeted scrape functions.
#
# Note: Be aware that we only take 40 because B&N website is terrible and will max out at 40 books per page. We may collect more data by scraping more than one page if we think it is neccessary for the purpose of our project.

# %%
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import WebDriverException

# %% [markdown]
# The reason we are using both Requests and Selenium Python libraries is due to the fact that some pages in B&N's website do not work with Requests, and for those pages we use Selenium.

# %%
#Make the list of subjects along with their urls. 

URL = "https://www.barnesandnoble.com/b/fiction/books/_/N-2usxZ29Z8q8"
page = requests.get(URL)
soup = BeautifulSoup(page.content, "html.parser")

results = soup.find(id="sidebar-section-FictionSubjects")

Sci_Fic_Thr = []
for litag in results.find_all('a'):
    if litag.text == 'Science Fiction & Fantasy' or litag.text == 'Thrillers' :
        Sci_Fic_Thr.append((str(litag).split('"')[1], litag.text.strip()))

# %%
Sci_Fic_Thr
# Out:
# [('/b/books/science-fiction-fantasy/_/N-29Z8q8Z180l',
#   'Science Fiction & Fantasy'),
#  ('/b/books/fiction/thrillers/_/N-29Z8q8Z1d3u', 'Thrillers')]

# %%
#Make the list of new releases along with their urls for the subjects Thrillers and Science Fiction & Fantasy.

def subjects_new_relases_url(list):
    new_releases_url = []
    for link in list:
        url = 'https://www.barnesandnoble.com' + link[0]
        page = requests.get(url)
        soup = BeautifulSoup(page.content, "html.parser")
        target = soup.find(id='hotBooksWithDesc_NewReleases')
        new_releases_url.append((str(target.find('a', class_='see-all-link')).split('"')[3],link[1]))
        
    return new_releases_url

# %%
subjects_new_relases_url(Sci_Fic_Thr)
# Out:
# [('/b/books/science-fiction-fantasy/_/N-1sZ29Z8q8Z180l?Ns=P_Sales_Rank',
#   'Science Fiction & Fantasy'),
#  ('/b/books/fiction/thrillers/_/N-1sZ29Z8q8Z1d3u?Ns=P_Sales_Rank',
#   'Thrillers')]

# %% [markdown]
# The new releases page by default only displays 20 books per page, but one can choose to show 40 books per page by choosing "show 40". The following code snippet accomplishes just that.

# %%
def show_40(list,begin,end):    
    show_40_list = []
    for i in range(begin,end):
        for link in list:
            url = 'https://www.barnesandnoble.com' + link[0].replace("s=P_Sales_Rank",f'rpp=40&Ns=P_Sales_Rank&page={i}')
            show_40_list.append((url,link[1]))
    return show_40_list

# %%
show_40(subjects_new_relases_url(Sci_Fic_Thr),1,3)[:5]
# Out:
# [('https://www.barnesandnoble.com/b/books/science-fiction-fantasy/_/N-1sZ29Z8q8Z180l?Nrpp=40&Ns=P_Sales_Rank&page=1',
#   'Science Fiction & Fantasy'),
#  ('https://www.barnesandnoble.com/b/books/fiction/thrillers/_/N-1sZ29Z8q8Z1d3u?Nrpp=40&Ns=P_Sales_Rank&page=1',
#   'Thrillers'),
#  ('https://www.barnesandnoble.com/b/books/science-fiction-fantasy/_/N-1sZ29Z8q8Z180l?Nrpp=40&Ns=P_Sales_Rank&page=2',
#   'Science Fiction & Fantasy'),
#  ('https://www.barnesandnoble.com/b/books/fiction/thrillers/_/N-1sZ29Z8q8Z1d3u?Nrpp=40&Ns=P_Sales_Rank&page=2',
#   'Thrillers')]

# %%
#Make the list containing the urls for all the newly released books along with their subjects.

def get_all_new_relases(list):
    
    chrome_options = Options()
    chrome_options.add_argument('--headless')
    browser = webdriver.Chrome(options=chrome_options)

    all_new_releases_url_list = []
    for x in list:
        browser.get(x[0])
        html = browser.page_source
        soup = BeautifulSoup(html, "html.parser")        
        target = soup.find_all('a', attrs = {'class' : 'pImageLink'})
        for y in target:
            a = str(y).split('"')[3]
            all_new_releases_url_list.append((a,x[1]))
    return all_new_releases_url_list

# %%
urls = get_all_new_relases(show_40(subjects_new_relases_url(Sci_Fic_Thr),1,6))

# %%
urls[:10]
# Out:
# [('/w/a-terrible-fall-of-angels-laurell-k-hamilton/1139142902;jsessionid=7E6181988B6D3C96B31F75E0F1CB050A.prodny_store02-va17?ean=9781984804464',
#   'Science Fiction & Fantasy'),
#  ('/w/king-bullet-richard-kadrey/1138272150;jsessionid=7E6181988B6D3C96B31F75E0F1CB050A.prodny_store02-va17?ean=9780062951588',
#   'Science Fiction & Fantasy'),
#  ('/w/paper-blood-kevin-hearne/1139998072;jsessionid=7E6181988B6D3C96B31F75E0F1CB050A.prodny_store02-va17?ean=9781984821287',
#   'Science Fiction & Fantasy'),
#  ('/w/starlight-enclave-r-a-salvatore/1138123720;jsessionid=7E6181988B6D3C96B31F75E0F1CB050A.prodny_store02-va17?ean=9780063214699',
#   'Science Fiction & Fantasy'),
#  ('/w/the-hidden-palace-helene-wecker/1138646126;jsessionid=7E6181988B6D3C96B31F75E0F1CB050A.prodny_store02-va17?ean=9780062468710',
#   'Science Fiction & Fantasy'),
#  ('/w/merely-magic-patricia-rice/1139840300;jsessionid=7E6181988B6D3C96B31F75E0F1CB050A.prodny_store02-va17?ean=2940162371359',
#   'Science Fiction & Fantasy'),
#  ('/w/million-dollar-demon-kim-harrison/1137713404;jsessionid=7E6181988B6D3C96B31F75E0F1CB050A.prodny_store02-va17?ean=9780593101445',
#   'Science Fiction & Fantasy'),
#  ('/w/the-rising-storm-cavan-scott/1138473187;jsessionid=7E6181988B6D3C96B31F75E0F1CB050A.prodny_store02-va17?ean=9780593358177',
#   'Science Fiction & Fantasy'),
#  ('/w/she-who-became-the-sun-shelley-parker-chan/1137525457;jsessionid=7E6181988B6D3C96B31F75E0F1CB050A.prodny_store02-va17?ean=9781250621801',
#   'Science Fiction & Fantasy'),
#  ('/w/nobodys-ghoul-devon-monk/1139723807;jsessionid=7E6181988B6D3C96B31F75E0F1CB050A.prodny_store02-va17?ean=2940162227939',
#   'Science Fiction & Fantasy')]

# %%
len(urls)
# Out:
# 400

# %%
#Get the title, author and summary for each newly released book while keeping track of what subject the book belongs to.

def get_data(list):
    
    chrome_options = Options()
    chrome_options.add_argument('--headless')
    browser = webdriver.Chrome(options=chrome_options)
    
    data_dict = {"title":[], "author":[], "overview":[], "subject":[]}
    for link in list:
        try:            
            url = 'https://www.barnesandnoble.com' + link[0]
            browser.get(url)
            html = browser.page_source
            soup = BeautifulSoup(html, 'html.parser')
        
            #get title
            title = soup.find('h1')
            title = str(title).split('>')[1].split('<')[0]
                
             #get author
            author = soup.find('span', attrs = {'id' : 'key-contributors'})
            author = str(author).split('>')[2].split('<')[0]
        
            
             #get summary if there is one
            overview = soup.find('div', attrs = {'class': 'overview-cntnt'})
            if overview:
                overview = overview.text.strip()
            else: 
                overview = 'None'
                
        except (IndexError, ValueError, WebDriverException):
            author = 'null'
            title = 'null'
            overview = 'null'
        
        data_dict["title"].append(title)
        data_dict["author"].append(author)
        data_dict["overview"].append(overview)
        data_dict["subject"].append(link[1])
            
                    
    return data_dict

# %%
data = get_data(urls)

# %%
import pandas as pd

# %%
df = pd.DataFrame.from_dict(data)

# %%
df
# Out:
#                                                  title               author  \
# 0                            A Terrible Fall of Angels  Laurell K. Hamilton
# 1                King Bullet (Sandman Slim Series #12)       Richard Kadrey
# 2        Paper &amp; Blood (Ink &amp; Sigil Series #2)         Kevin Hearne
# 3                      Starlight Enclave (Signed Book)      R. A. Salvatore
# 4    The Hidden Palace: A Novel of the Golem and th...        Helene Wecker
# ..                                                 ...                  ...
# 395                                 The Sleeping Nymph          Ilaria Tuti
# 396                                  Seeking Salvation       Carla Barandas
# 397                                 Friend of a Friend      James V. Irving
# 398                    Red War (Mitch Rapp Series #17)          Vince Flynn
# 399                             When the Sparrow Falls        Neil Sharpson
#
#                                               overview  \
# 0    Angels walk among us, but so do other unearthl...
# 1    The incredible finale of the page-turning, hig...
# 2    From the New York Times bestselling author of ...
# 3    From New York Times bestselling author R. A. S...
# 4    "Richly nuanced and beautiful. . . . An immers...
# ..                                                 ...
# 395  A 2021 Sue Grafton Memorial Award NomineeIn th...
# 396  Four doctors sent on a mission for one of the ...
# 397  When an investigation threatens his lucrative ...
# 398  This instant #1 New York Times bestseller and ...
# 399  Life in the Caspian Republic has taught Agent ...
#
#                        subject
# 0    Science Fiction & Fantasy
# 1    Science Fiction & Fantasy
# 2    Science Fiction & Fantasy
# 3    Science Fiction & Fantasy
# 4    Science Fiction & Fantasy
# ..                         ...
# 395                  Thrillers
# 396                  Thrillers
# 397                  Thrillers
# 398                  Thrillers
# 399                  Thrillers
#
# [400 rows x 4 columns]

# %%
urls1 = get_all_new_relases(show_40(subjects_new_relases_url(Sci_Fic_Thr),6,11))

# %%
data1 = get_data(urls1)

# %%
df1 = pd.DataFrame.from_dict(data1)

# %%
df1
# Out:
#                                                  title             author  \
# 0    The Shackled Verities Complete Collection Box Set       Tammy Salyer
# 1                                     War and the Wind       Tyler Krings
# 2    The Lifehouse Trilogy (Mindkiller, Time Pressu...    Spider Robinson
# 3    The Hero Is Overpowered But Overly Cautious, V...      Light Tuchihi
# 4                                                Hella      David Gerrold
# ..                                                 ...                ...
# 395                                               Pain        Adam Turner
# 396                              On demande un cadavre      Frédéric DARD
# 397                                    Cigarette Break         Paul Weiss
# 398                                          Notchwood  Benjamin Mailloux
# 399                                               2044     Timothy Ruplin
#
#                                               overview  \
# 0    The fate of this world may rest on our shoulde...
# 1    The war in Anu is over. The Lord of Fate has u...
# 2    THE LIFEHOUSE TRILOGY is comprised of three bo...
# 3    Is it time for Seiya’s bag carriers to fulfill...
# 4    A master of science fiction introduces a world...
# ..                                                 ...
# 395  PainBy: Adam TurnerAfter Sky blamed her years ...
# 396  Alfredo Seruti, un mafieux anglais, envoie deu...
# 397  FICTION: From its perch in The Castle, an aban...
# 398  Down on his luck, Allen Notchwood tries to for...
# 399  After America's drug war ended, in complete ab...
#
#                        subject
# 0    Science Fiction & Fantasy
# 1    Science Fiction & Fantasy
# 2    Science Fiction & Fantasy
# 3    Science Fiction & Fantasy
# 4    Science Fiction & Fantasy
# ..                         ...
# 395                  Thrillers
# 396                  Thrillers
# 397                  Thrillers
# 398                  Thrillers
# 399                  Thrillers
#
# [400 rows x 4 columns]

# %%
urls2 = get_all_new_relases(show_40(subjects_new_relases_url(Sci_Fic_Thr),11,16))

# %%
data2 = get_data(urls2)

# %%
df2 = pd.DataFrame.from_dict(data2)

# %%
df2
# Out:
#                                         title               author  \
# 0                            Savage: The Wild            Max Bemis
# 1                                   Phase Six          Jim Shepard
# 2               The AOA (Season 1: Episode 3)  Kester James Finley
# 3                       The Heads of Cerberus      Francis Stevens
# 4      The Wind Rose (The Moon Singer Book 3)             B. Roman
# ..                                        ...                  ...
# 395                                White Fang          Jack London
# 396    Pharos the Egyptian (Esprios Classics)          Guy Boothby
# 397                       A Plague of Dissent           Nic Taylor
# 398    Distortions: A Quinn Masterson Mystery    James M. Campbell
# 399  The Chameleon Fallacy (Bamboo Books, #2)        Shane Norwood
#
#                                               overview  \
# 0    Teenage heartthrob. Feral social icon. Dinosau...
# 1    A spare and gripping novel about the next pand...
# 2    After facing the villainous Reclaimer, Becca i...
# 3    The Heads of Cerberus (1919) is a science fict...
# 4    In this third and final adventure of the Moon ...
# ..                                                 ...
# 395  White Fang is a novel by American author Jack ...
# 396  Guy Newell Boothby (1867-1905) was a prolific ...
# 397  In a world where media companies hack into per...
# 398  A message scrawled at a murder scene beckons D...
# 399  At the conclusion of Machine Gun Jelly it look...
#
#                        subject
# 0    Science Fiction & Fantasy
# 1    Science Fiction & Fantasy
# 2    Science Fiction & Fantasy
# 3    Science Fiction & Fantasy
# 4    Science Fiction & Fantasy
# ..                         ...
# 395                  Thrillers
# 396                  Thrillers
# 397                  Thrillers
# 398                  Thrillers
# 399                  Thrillers
#
# [400 rows x 4 columns]

# %%
urls3 = get_all_new_relases(show_40(subjects_new_relases_url(Sci_Fic_Thr),16,21))

# %%
data3 = get_data(urls3)

# %%
df3 = pd.DataFrame.from_dict(data3)

# %%
df3
# Out:
#                                                  title                author  \
# 0                                    Edifice Abandoned  Scott Michael Decker
# 1                                          The Phantom       Frank Settineri
# 2    The Bonds of Osteria: Book Four of the Osteria...        Tammie Painter
# 3                       Soul Savers Box Set: Books 1-3          Kristie Cook
# 4                Visigothic: The Barbarians of Midgard           Jay Newcomb
# ..                                                 ...                   ...
# 395  Amazonia's Mythical and Legendary Creatures in...          Damon Corrie
# 396    Taunusschuld: Zweiter Fall für Melanie Gramberg          Osvin Nöller
# 397                                   The Soul Traders                  REMI
# 398                                 Blood on the Bayou       D. J. Donaldson
# 399                                       Backtracking       Martin S. Baker
#
#                                               overview  \
# 0    Studying ancient sites on a backwater planet, ...
# 1    The Phantom is a realistic fantasy about Tarch...
# 2    In a fierce clash for power, titans rise, hero...
# 3    This boxset delivers the first three books in ...
# 4                                                 None
# ..                                                 ...
# 395  Included are real-life oral tradition accounts...
# 396  Jede Schuld ist zu begleichen! Die eine früher...
# 397  The Soul Traders By: REMIGhosts, both good and...
# 398  Don Donaldson brings us to the famous French Q...
# 399  Going to war was never a good idea and taking ...
#
#                        subject
# 0    Science Fiction & Fantasy
# 1    Science Fiction & Fantasy
# 2    Science Fiction & Fantasy
# 3    Science Fiction & Fantasy
# 4    Science Fiction & Fantasy
# ..                         ...
# 395                  Thrillers
# 396                  Thrillers
# 397                  Thrillers
# 398                  Thrillers
# 399                  Thrillers
#
# [400 rows x 4 columns]

# %%
urls4 = get_all_new_relases(show_40(subjects_new_relases_url(Sci_Fic_Thr),21,26))

# %%
data4 = get_data(urls4)

# %%
df4 = pd.DataFrame.from_dict(data4)

# %%
df4
# Out:
#                                 title              author  \
# 0                  The Nature of Mars  Dr. Patch Lieveert
# 1    Don Rodriguez (Esprios Classics)        Lord Dunsany
# 2                      A Book of This      Mackenzie Judd
# 3                   The Cursed Spirit       Lilliana Rose
# 4                      The 24hourlies         Gaja J. Kos
# ..                                ...                 ...
# 395                     Book of Water        Robin Brande
# 396                          The Poet    Lisa Renee Jones
# 397    Future Ghost / Speedin' Bullet          Jack Grant
# 398              King Solomon's Mines    H. Rider Haggard
# 399  Sunshine: The Intrusion: A Novel     Thomas G. Elmer
#
#                                               overview  \
# 0    The Nature of MarsBy:  Dr. Patch LieveertAs hu...
# 1    Edward John Moreton Drax Plunkett, 18th Baron ...
# 2    Dr. Richards works for a mysterious Head Offic...
# 3    The Lost Souls Academy has become Zarya's home...
# 4    The ascension to The Dark Ones had brought Ros...
# ..                                                 ...
# 395  Bradamante is camped with the king’s army in t...
# 396  New York Times bestselling author Lisa Renee J...
# 397  'Future Ghost' and 'Speedin' Bullet' are the t...
# 398  It is a curious thing that at my age-fifty-fiv...
# 399  A floatplane attempts to land on the lake wate...
#
#                        subject
# 0    Science Fiction & Fantasy
# 1    Science Fiction & Fantasy
# 2    Science Fiction & Fantasy
# 3    Science Fiction & Fantasy
# 4    Science Fiction & Fantasy
# ..                         ...
# 395                  Thrillers
# 396                  Thrillers
# 397                  Thrillers
# 398                  Thrillers
# 399                  Thrillers
#
# [400 rows x 4 columns]

# %%
Data = df.append([df1,df2,df3,df4])

# %%
Data
# Out:
#                                                  title               author  \
# 0                            A Terrible Fall of Angels  Laurell K. Hamilton
# 1                King Bullet (Sandman Slim Series #12)       Richard Kadrey
# 2        Paper &amp; Blood (Ink &amp; Sigil Series #2)         Kevin Hearne
# 3                      Starlight Enclave (Signed Book)      R. A. Salvatore
# 4    The Hidden Palace: A Novel of the Golem and th...        Helene Wecker
# ..                                                 ...                  ...
# 395                                      Book of Water         Robin Brande
# 396                                           The Poet     Lisa Renee Jones
# 397                     Future Ghost / Speedin' Bullet           Jack Grant
# 398                               King Solomon's Mines     H. Rider Haggard
# 399                   Sunshine: The Intrusion: A Novel      Thomas G. Elmer
#
#                                               overview  \
# 0    Angels walk among us, but so do other unearthl...
# 1    The incredible finale of the page-turning, hig...
# 2    From the New York Times bestselling author of ...
# 3    From New York Times bestselling author R. A. S...
# 4    "Richly nuanced and beautiful. . . . An immers...
# ..                                                 ...
# 395  Bradamante is camped with the king’s army in t...
# 396  New York Times bestselling author Lisa Renee J...
# 397  'Future Ghost' and 'Speedin' Bullet' are the t...
# 398  It is a curious thing that at my age-fifty-fiv...
# 399  A floatplane attempts to land on the lake wate...
#
#                        subject
# 0    Science Fiction & Fantasy
# 1    Science Fiction & Fantasy
# 2    Science Fiction & Fantasy
# 3    Science Fiction & Fantasy
# 4    Science Fiction & Fantasy
# ..                         ...
# 395                  Thrillers
# 396                  Thrillers
# 397                  Thrillers
# 398                  Thrillers
# 399                  Thrillers
#
# [2000 rows x 4 columns]

# %%
Data = Data.drop_duplicates()

# %%
Data
# Out:
#                                                  title               author  \
# 0                            A Terrible Fall of Angels  Laurell K. Hamilton
# 1                King Bullet (Sandman Slim Series #12)       Richard Kadrey
# 2        Paper &amp; Blood (Ink &amp; Sigil Series #2)         Kevin Hearne
# 3                      Starlight Enclave (Signed Book)      R. A. Salvatore
# 4    The Hidden Palace: A Novel of the Golem and th...        Helene Wecker
# ..                                                 ...                  ...
# 395                                      Book of Water         Robin Brande
# 396                                           The Poet     Lisa Renee Jones
# 397                     Future Ghost / Speedin' Bullet           Jack Grant
# 398                               King Solomon's Mines     H. Rider Haggard
# 399                   Sunshine: The Intrusion: A Novel      Thomas G. Elmer
#
#                                               overview  \
# 0    Angels walk among us, but so do other unearthl...
# 1    The incredible finale of the page-turning, hig...
# 2    From the New York Times bestselling author of ...
# 3    From New York Times bestselling author R. A. S...
# 4    "Richly nuanced and beautiful. . . . An immers...
# ..                                                 ...
# 395  Bradamante is camped with the king’s army in t...
# 396  New York Times bestselling author Lisa Renee J...
# 397  'Future Ghost' and 'Speedin' Bullet' are the t...
# 398  It is a curious thing that at my age-fifty-fiv...
# 399  A floatplane attempts to land on the lake wate...
#
#                        subject
# 0    Science Fiction & Fantasy
# 1    Science Fiction & Fantasy
# 2    Science Fiction & Fantasy
# 3    Science Fiction & Fantasy
# 4    Science Fiction & Fantasy
# ..                         ...
# 395                  Thrillers
# 396                  Thrillers
# 397                  Thrillers
# 398                  Thrillers
# 399                  Thrillers
#
# [1992 rows x 4 columns]

# %%
Data.value_counts(subset = 'subject')
# Out:
# subject
# Science Fiction & Fantasy    998
# Thrillers                    994
# dtype: int64

# %%
Data.to_csv('new_releases_Thriller and SciFi&Fantasy.csv', index=False)
